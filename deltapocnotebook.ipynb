# %%
# %sql

drop database demo_db cascade;
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# com.databricks.backend.common.rpc.DatabricksExceptions$SQLExecutionException: org.apache.spark.sql.AnalysisException: org.apache.hadoop.hive.metastore.api.NoSuchObjectException: There is no database named demo_db;
# 	at org.apache.spark.sql.hive.HiveExternalCatalog.$anonfun$withClient$2(HiveExternalCatalog.scala:159)
# 	at org.apache.spark.sql.hive.HiveExternalCatalog.maybeSynchronized(HiveExternalCatalog.scala:110)
# 	at org.apache.spark.sql.hive.HiveExternalCatalog.$anonfun$withClient$1(HiveExternalCatalog.scala:148)
# 	at com.databricks.backend.daemon.driver.ProgressReporter$.withStatusCode(ProgressReporter.scala:377)
# 	at com.databricks.backend.daemon.driver.ProgressReporter$.withStatusCode(ProgressReporter.scala:363)
# 	at com.databricks.spark.util.SparkDatabricksProgressReporter$.withStatusCode(ProgressReporter.scala:34)
# 	at org.apache.spark.sql.hive.HiveExternalCatalog.withClient(HiveExternalCatalog.scala:147)
# 	at org.apache.spark.sql.hive.HiveExternalCatalog.dropDatabase(HiveExternalCatalog.scala:263)
# 	at org.apache.spark.sql.catalyst.catalog.ExternalCatalogWithListener.dropDatabase(ExternalCatalogWithListener.scala:58)
# 	at org.apache.spark.sql.catalyst.catalog.SessionCatalog.dropDatabase(SessionCatalog.scala:260)
# 	at org.apache.spark.sql.execution.command.DropDatabaseCommand.run(ddl.scala:113)
# 	at org.apache.spark.sql.execution.command.ExecutedCommandExec.sideEffectResult$lzycompute(commands.scala:70)
# 	at org.apache.spark.sql.execution.command.ExecutedCommandExec.sideEffectResult(commands.scala:68)
# 	at org.apache.spark.sql.execution.command.ExecutedCommandExec.executeCollect(commands.scala:79)
# 	at org.apache.spark.sql.Dataset.$anonfun$logicalPlan$1(Dataset.scala:234)
# 	at org.apache.spark.sql.Dataset.$anonfun$withAction$1(Dataset.scala:3757)
# 	at org.apache.spark.sql.execution.SQLExecution$.$anonfun$withCustomExecutionEnv$5(SQLExecution.scala:116)
# 	at org.apache.spark.sql.execution.SQLExecution$.withSQLConfPropagated(SQLExecution.scala:248)
# 	at org.apache.spark.sql.execution.SQLExecution$.$anonfun$withCustomExecutionEnv$1(SQLExecution.scala:101)
# 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:841)
# 	at org.apache.spark.sql.execution.SQLExecution$.withCustomExecutionEnv(SQLExecution.scala:77)
# 	at org.apache.spark.sql.execution.SQLExecution$.withNewExecutionId(SQLExecution.scala:198)
# 	at org.apache.spark.sql.Dataset.withAction(Dataset.scala:3755)
# 	at org.apache.spark.sql.Dataset.<init>(Dataset.scala:234)
# 	at org.apache.spark.sql.Dataset$.$anonfun$ofRows$2(Dataset.scala:104)
# 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:841)
# 	at org.apache.spark.sql.Dataset$.ofRows(Dataset.scala:101)
# 	at org.apache.spark.sql.SparkSession.$anonfun$sql$1(SparkSession.scala:676)
# 	at org.apache.spark.sql.SparkSession.withActive(SparkSession.scala:841)
# 	at org.apache.spark.sql.SparkSession.sql(SparkSession.scala:671)
# 	at org.apache.spark.sql.SQLContext.sql(SQLContext.scala:672)
# 	at com.databricks.backend.daemon.driver.SQLDriverLocal.$anonfun$executeSql$1(SQLDriverLocal.scala:91)
# 	at scala.collection.TraversableLike.$anonfun$map$1(TraversableLike.scala:238)
# 	at scala.collection.immutable.List.foreach(List.scala:392)
# 	at scala.collection.TraversableLike.map(TraversableLike.scala:238)
# 	at scala.collection.TraversableLike.map$(TraversableLike.scala:231)
# 	at scala.collection.immutable.List.map(List.scala:298)
# 	at com.databricks.backend.daemon.driver.SQLDriverLocal.executeSql(SQLDriverLocal.scala:37)
# 	at com.databricks.backend.daemon.driver.SQLDriverLocal.repl(SQLDriverLocal.scala:144)
# 	at com.databricks.backend.daemon.driver.DriverLocal.$anonfun$execute$10(DriverLocal.scala:431)
# 	at com.databricks.logging.UsageLogging.$anonfun$withAttributionContext$1(UsageLogging.scala:239)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at com.databricks.logging.UsageLogging.withAttributionContext(UsageLogging.scala:234)
# 	at com.databricks.logging.UsageLogging.withAttributionContext$(UsageLogging.scala:231)
# 	at com.databricks.backend.daemon.driver.DriverLocal.withAttributionContext(DriverLocal.scala:48)
# 	at com.databricks.logging.UsageLogging.withAttributionTags(UsageLogging.scala:276)
# 	at com.databricks.logging.UsageLogging.withAttributionTags$(UsageLogging.scala:269)
# 	at com.databricks.backend.daemon.driver.DriverLocal.withAttributionTags(DriverLocal.scala:48)
# 	at com.databricks.backend.daemon.driver.DriverLocal.execute(DriverLocal.scala:408)
# 	at com.databricks.backend.daemon.driver.DriverWrapper.$anonfun$tryExecutingCommand$1(DriverWrapper.scala:690)
# 	at scala.util.Try$.apply(Try.scala:213)
# 	at com.databricks.backend.daemon.driver.DriverWrapper.tryExecutingCommand(DriverWrapper.scala:682)
# 	at com.databricks.backend.daemon.driver.DriverWrapper.getCommandOutputAndError(DriverWrapper.scala:523)
# 	at com.databricks.backend.daemon.driver.DriverWrapper.executeCommand(DriverWrapper.scala:635)
# 	at com.databricks.backend.daemon.driver.DriverWrapper.runInnerLoop(DriverWrapper.scala:428)
# 	at com.databricks.backend.daemon.driver.DriverWrapper.runInner(DriverWrapper.scala:371)
# 	at com.databricks.backend.daemon.driver.DriverWrapper.run(DriverWrapper.scala:223)
# 	at java.lang.Thread.run(Thread.java:748)
# Caused by: NoSuchObjectException(message:There is no database named demo_db)
# 	at org.apache.hadoop.hive.metastore.ObjectStore.getMDatabase(ObjectStore.java:487)
# 	at org.apache.hadoop.hive.metastore.ObjectStore.getDatabase(ObjectStore.java:498)
# 	at sun.reflect.GeneratedMethodAccessor130.invoke(Unknown Source)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at org.apache.hadoop.hive.metastore.RawStoreProxy.invoke(RawStoreProxy.java:108)
# 	at com.sun.proxy.$Proxy60.getDatabase(Unknown Source)
# 	at org.apache.hadoop.hive.metastore.HiveMetaStore$HMSHandler.get_database(HiveMetaStore.java:796)
# 	at sun.reflect.GeneratedMethodAccessor138.invoke(Unknown Source)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at org.apache.hadoop.hive.metastore.RetryingHMSHandler.invoke(RetryingHMSHandler.java:105)
# 	at com.sun.proxy.$Proxy61.get_database(Unknown Source)
# 	at org.apache.hadoop.hive.metastore.HiveMetaStoreClient.getDatabase(HiveMetaStoreClient.java:949)
# 	at org.apache.hadoop.hive.metastore.HiveMetaStoreClient.dropDatabase(HiveMetaStoreClient.java:608)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at org.apache.hadoop.hive.metastore.RetryingMetaStoreClient.invoke(RetryingMetaStoreClient.java:89)
# 	at com.sun.proxy.$Proxy62.dropDatabase(Unknown Source)
# 	at org.apache.hadoop.hive.ql.metadata.Hive.dropDatabase(Hive.java:299)
# 	at org.apache.spark.sql.hive.client.HiveClientImpl.$anonfun$dropDatabase$1(HiveClientImpl.scala:401)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.sql.hive.client.HiveClientImpl.$anonfun$withHiveState$1(HiveClientImpl.scala:349)
# 	at org.apache.spark.sql.hive.client.HiveClientImpl.$anonfun$retryLocked$1(HiveClientImpl.scala:252)
# 	at org.apache.spark.sql.hive.client.HiveClientImpl.synchronizeOnObject(HiveClientImpl.scala:288)
# 	at org.apache.spark.sql.hive.client.HiveClientImpl.retryLocked(HiveClientImpl.scala:244)
# 	at org.apache.spark.sql.hive.client.HiveClientImpl.withHiveState(HiveClientImpl.scala:331)
# 	at org.apache.spark.sql.hive.client.HiveClientImpl.dropDatabase(HiveC

# %%
from pyspark.sql import Row
l=[(2001, "Iphone12", 11, "I"), (2002, "One plus7", 33, "I"), (2003, "Redminote10", 41, "I"), (2004, "Samsung S10", 14, "I")]
rdd = sc.parallelize(l)
schema_rdd=rdd.map(lambda x : Row(product_id = int(x[0]), product_name = x[1], stocks_left = int(x[2]), opn_flag=x[3] ))
df=spark.createDataFrame(schema_rdd)
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_id</th><th>product_name</th><th>stocks_left</th><th>opn_flag</th></tr></thead><tbody><tr><td>2001</td><td>Iphone12</td><td>11</td><td>I</td></tr><tr><td>2002</td><td>One plus7</td><td>33</td><td>I</td></tr><tr><td>2003</td><td>Redminote10</td><td>41</td><td>I</td></tr><tr><td>2004</td><td>Samsung S10</td><td>14</td><td>I</td></tr></tbody></table></div>

# %%
# %sql

create database demo_db;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
database_name = 'demo_db'
delta_table_name = 'product_delta_table'
parquet_table_name = "product_parquet_table"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
(df.coalesce(2).write.format("parquet").mode("overwrite").saveAsTable(f'{database_name}.{parquet_table_name}'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %fs

ls dbfs:/user/hive/warehouse/demo_db.db/product_parquet_table
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/user/hive/warehouse/demo_db.db/product_parquet_table/_SUCCESS</td><td>_SUCCESS</td><td>0</td></tr><tr><td>dbfs:/user/hive/warehouse/demo_db.db/product_parquet_table/_committed_5959910327175640031</td><td>_committed_5959910327175640031</td><td>224</td></tr><tr><td>dbfs:/user/hive/warehouse/demo_db.db/product_parquet_table/_started_5959910327175640031</td><td>_started_5959910327175640031</td><td>0</td></tr><tr><td>dbfs:/user/hive/warehouse/demo_db.db/product_parquet_table/part-00000-tid-5959910327175640031-e0e9e928-9ba6-49cb-b229-4483aaaa38fe-202-1-c000.snappy.parquet</td><td>part-00000-tid-5959910327175640031-e0e9e928-9ba6-49cb-b229-4483aaaa38fe-202-1-c000.snappy.parquet</td><td>1265</td></tr><tr><td>dbfs:/user/hive/warehouse/demo_db.db/product_parquet_table/part-00001-tid-5959910327175640031-e0e9e928-9ba6-49cb-b229-4483aaaa38fe-203-1-c000.snappy.parquet</td><td>part-00001-tid-5959910327175640031-e0e9e928-9ba6-49cb-b229-4483aaaa38fe-203-1-c000.snappy.parquet</td><td>1280</td></tr></tbody></table></div>

# %%
(df.coalesce(2).write.format("parquet").mode("overwrite").saveAsTable(f'{database_name}.{parquet_table_name}'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %fs

ls dbfs:/user/hive/warehouse/demo_db.db/product_parquet_table
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/user/hive/warehouse/demo_db.db/product_parquet_table/_SUCCESS</td><td>_SUCCESS</td><td>0</td></tr><tr><td>dbfs:/user/hive/warehouse/demo_db.db/product_parquet_table/_committed_2500226590708865679</td><td>_committed_2500226590708865679</td><td>224</td></tr><tr><td>dbfs:/user/hive/warehouse/demo_db.db/product_parquet_table/_started_2500226590708865679</td><td>_started_2500226590708865679</td><td>0</td></tr><tr><td>dbfs:/user/hive/warehouse/demo_db.db/product_parquet_table/part-00000-tid-2500226590708865679-a13c5d9c-65a2-4f34-99ce-43e106d60e61-204-1-c000.snappy.parquet</td><td>part-00000-tid-2500226590708865679-a13c5d9c-65a2-4f34-99ce-43e106d60e61-204-1-c000.snappy.parquet</td><td>1265</td></tr><tr><td>dbfs:/user/hive/warehouse/demo_db.db/product_parquet_table/part-00001-tid-2500226590708865679-a13c5d9c-65a2-4f34-99ce-43e106d60e61-205-1-c000.snappy.parquet</td><td>part-00001-tid-2500226590708865679-a13c5d9c-65a2-4f34-99ce-43e106d60e61-205-1-c000.snappy.parquet</td><td>1280</td></tr></tbody></table></div>

# %%
(df.coalesce(2).write.format("delta").mode("overwrite").saveAsTable(f'{database_name}.{delta_table_name}'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %fs

ls dbfs:/user/hive/warehouse/demo_db.db/product_delta_table
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/user/hive/warehouse/demo_db.db/product_delta_table/_delta_log/</td><td>_delta_log/</td><td>0</td></tr><tr><td>dbfs:/user/hive/warehouse/demo_db.db/product_delta_table/part-00000-e696e70b-981d-4d92-ab99-d3cfd354a15d-c000.snappy.parquet</td><td>part-00000-e696e70b-981d-4d92-ab99-d3cfd354a15d-c000.snappy.parquet</td><td>1265</td></tr><tr><td>dbfs:/user/hive/warehouse/demo_db.db/product_delta_table/part-00001-5a191187-0e1d-418b-9265-6f04a3b69af2-c000.snappy.parquet</td><td>part-00001-5a191187-0e1d-418b-9265-6f04a3b69af2-c000.snappy.parquet</td><td>1280</td></tr></tbody></table></div>

# %%
# %fs
ls dbfs:/user/hive/warehouse/demo_db.db/product_delta_table/_delta_log
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/user/hive/warehouse/demo_db.db/product_delta_table/_delta_log/00000000000000000000.crc</td><td>00000000000000000000.crc</td><td>89</td></tr><tr><td>dbfs:/user/hive/warehouse/demo_db.db/product_delta_table/_delta_log/00000000000000000000.json</td><td>00000000000000000000.json</td><td>2063</td></tr><tr><td>dbfs:/user/hive/warehouse/demo_db.db/product_delta_table/_delta_log/__tmp_path_dir/</td><td>__tmp_path_dir/</td><td>0</td></tr></tbody></table></div>

# %%
(df.coalesce(2).write.format("delta").mode("overwrite").saveAsTable(f'{database_name}.{delta_table_name}'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %fs

ls dbfs:/user/hive/warehouse/demo_db.db/product_delta_table
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/user/hive/warehouse/demo_db.db/product_delta_table/_delta_log/</td><td>_delta_log/</td><td>0</td></tr><tr><td>dbfs:/user/hive/warehouse/demo_db.db/product_delta_table/part-00000-04e318b5-516a-4ea2-a80a-3aa5c27f1232-c000.snappy.parquet</td><td>part-00000-04e318b5-516a-4ea2-a80a-3aa5c27f1232-c000.snappy.parquet</td><td>1265</td></tr><tr><td>dbfs:/user/hive/warehouse/demo_db.db/product_delta_table/part-00000-e696e70b-981d-4d92-ab99-d3cfd354a15d-c000.snappy.parquet</td><td>part-00000-e696e70b-981d-4d92-ab99-d3cfd354a15d-c000.snappy.parquet</td><td>1265</td></tr><tr><td>dbfs:/user/hive/warehouse/demo_db.db/product_delta_table/part-00001-5a191187-0e1d-418b-9265-6f04a3b69af2-c000.snappy.parquet</td><td>part-00001-5a191187-0e1d-418b-9265-6f04a3b69af2-c000.snappy.parquet</td><td>1280</td></tr><tr><td>dbfs:/user/hive/warehouse/demo_db.db/product_delta_table/part-00001-a3062155-b29a-49a4-bfa6-26d4f4d1f4b1-c000.snappy.parquet</td><td>part-00001-a3062155-b29a-49a4-bfa6-26d4f4d1f4b1-c000.snappy.parquet</td><td>1280</td></tr></tbody></table></div>

# %%
# %fs

ls dbfs:/user/hive/warehouse/demo_db.db/product_delta_table/_delta_log
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/user/hive/warehouse/demo_db.db/product_delta_table/_delta_log/00000000000000000000.crc</td><td>00000000000000000000.crc</td><td>89</td></tr><tr><td>dbfs:/user/hive/warehouse/demo_db.db/product_delta_table/_delta_log/00000000000000000000.json</td><td>00000000000000000000.json</td><td>2063</td></tr><tr><td>dbfs:/user/hive/warehouse/demo_db.db/product_delta_table/_delta_log/00000000000000000001.crc</td><td>00000000000000000001.crc</td><td>89</td></tr><tr><td>dbfs:/user/hive/warehouse/demo_db.db/product_delta_table/_delta_log/00000000000000000001.json</td><td>00000000000000000001.json</td><td>1764</td></tr><tr><td>dbfs:/user/hive/warehouse/demo_db.db/product_delta_table/_delta_log/__tmp_path_dir/</td><td>__tmp_path_dir/</td><td>0</td></tr></tbody></table></div>

# %%
# %fs

head dbfs:/user/hive/warehouse/demo_db.db/product_delta_table/_delta_log/00000000000000000000.json
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">{&quot;commitInfo&quot;:{&quot;timestamp&quot;:1608798278869,&quot;userId&quot;:&quot;256656542290214&quot;,&quot;userName&quot;:&quot;ravi.tiwari@nagarro.com&quot;,&quot;operation&quot;:&quot;CREATE OR REPLACE TABLE AS SELECT&quot;,&quot;operationParameters&quot;:{&quot;isManaged&quot;:&quot;true&quot;,&quot;description&quot;:null,&quot;partitionBy&quot;:&quot;[]&quot;,&quot;properties&quot;:&quot;{}&quot;},&quot;notebook&quot;:{&quot;notebookId&quot;:&quot;4496351827461139&quot;},&quot;clusterId&quot;:&quot;1222-072542-imp140&quot;,&quot;isolationLevel&quot;:&quot;WriteSerializable&quot;,&quot;isBlindAppend&quot;:false,&quot;operationMetrics&quot;:{&quot;numFiles&quot;:&quot;2&quot;,&quot;numOutputBytes&quot;:&quot;2545&quot;,&quot;numOutputRows&quot;:&quot;4&quot;}}}
# {&quot;protocol&quot;:{&quot;minReaderVersion&quot;:1,&quot;minWriterVersion&quot;:2}}
# {&quot;metaData&quot;:{&quot;id&quot;:&quot;e689f527-4391-441d-b7de-3975f971bae1&quot;,&quot;format&quot;:{&quot;provider&quot;:&quot;parquet&quot;,&quot;options&quot;:{}},&quot;schemaString&quot;:&quot;{\&quot;type\&quot;:\&quot;struct\&quot;,\&quot;fields\&quot;:[{\&quot;name\&quot;:\&quot;product_id\&quot;,\&quot;type\&quot;:\&quot;long\&quot;,\&quot;nullable\&quot;:true,\&quot;metadata\&quot;:{}},{\&quot;name\&quot;:\&quot;product_name\&quot;,\&quot;type\&quot;:\&quot;string\&quot;,\&quot;nullable\&quot;:true,\&quot;metadata\&quot;:{}},{\&quot;name\&quot;:\&quot;stocks_left\&quot;,\&quot;type\&quot;:\&quot;long\&quot;,\&quot;nullable\&quot;:true,\&quot;metadata\&quot;:{}},{\&quot;name\&quot;:\&quot;opn_flag\&quot;,\&quot;type\&quot;:\&quot;string\&quot;,\&quot;nullable\&quot;:true,\&quot;metadata\&quot;:{}}]}&quot;,&quot;partitionColumns&quot;:[],&quot;configuration&quot;:{},&quot;createdTime&quot;:1608798278222}}
# {&quot;add&quot;:{&quot;path&quot;:&quot;part-00000-e696e70b-981d-4d92-ab99-d3cfd354a15d-c000.snappy.parquet&quot;,&quot;partitionValues&quot;:{},&quot;size&quot;:1265,&quot;modificationTime&quot;:1608798278000,&quot;dataChange&quot;:true,&quot;stats&quot;:&quot;{\&quot;numRecords\&quot;:2,\&quot;minValues\&quot;:{\&quot;product_id\&quot;:2001,\&quot;product_name\&quot;:\&quot;Iphone12\&quot;,\&quot;stocks_left\&quot;:11,\&quot;opn_flag\&quot;:\&quot;I\&quot;},\&quot;maxValues\&quot;:{\&quot;product_id\&quot;:2002,\&quot;product_name\&quot;:\&quot;One plus7\&quot;,\&quot;stocks_left\&quot;:33,\&quot;opn_flag\&quot;:\&quot;I\&quot;},\&quot;nullCount\&quot;:{\&quot;product_id\&quot;:0,\&quot;product_name\&quot;:0,\&quot;stocks_left\&quot;:0,\&quot;opn_flag\&quot;:0}}&quot;}}
# {&quot;add&quot;:{&quot;path&quot;:&quot;part-00001-5a191187-0e1d-418b-9265-6f04a3b69af2-c000.snappy.parquet&quot;,&quot;partitionValues&quot;:{},&quot;size&quot;:1280,&quot;modificationTime&quot;:1608798278000,&quot;dataChange&quot;:true,&quot;stats&quot;:&quot;{\&quot;numRecords\&quot;:2,\&quot;minValues\&quot;:{\&quot;product_id\&quot;:2003,\&quot;product_name\&quot;:\&quot;Redminote10\&quot;,\&quot;stocks_left\&quot;:14,\&quot;opn_flag\&quot;:\&quot;I\&quot;},\&quot;maxValues\&quot;:{\&quot;product_id\&quot;:2004,\&quot;product_name\&quot;:\&quot;Samsung S10\&quot;,\&quot;stocks_left\&quot;:41,\&quot;opn_flag\&quot;:\&quot;I\&quot;},\&quot;nullCount\&quot;:{\&quot;product_id\&quot;:0,\&quot;product_name\&quot;:0,\&quot;stocks_left\&quot;:0,\&quot;opn_flag\&quot;:0}}&quot;}}
#
# </div>

# %%
display(spark.read.json('dbfs:/user/hive/warehouse/demo_db.db/product_delta_table/_delta_log/00000000000000000000.json'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>add</th><th>commitInfo</th><th>metaData</th><th>protocol</th></tr></thead><tbody><tr><td>null</td><td>List(1222-072542-imp140, false, WriteSerializable, List(4496351827461139), CREATE OR REPLACE TABLE AS SELECT, List(2, 2545, 4), List(null, true, [], {}), 1608798278869, 256656542290214, ravi.tiwari@nagarro.com)</td><td>null</td><td>null</td></tr><tr><td>null</td><td>null</td><td>null</td><td>List(1, 2)</td></tr><tr><td>null</td><td>null</td><td>List(1608798278222, List(parquet), e689f527-4391-441d-b7de-3975f971bae1, List(), {"type":"struct","fields":[{"name":"product_id","type":"long","nullable":true,"metadata":{}},{"name":"product_name","type":"string","nullable":true,"metadata":{}},{"name":"stocks_left","type":"long","nullable":true,"metadata":{}},{"name":"opn_flag","type":"string","nullable":true,"metadata":{}}]})</td><td>null</td></tr><tr><td>List(true, 1608798278000, part-00000-e696e70b-981d-4d92-ab99-d3cfd354a15d-c000.snappy.parquet, 1265, {"numRecords":2,"minValues":{"product_id":2001,"product_name":"Iphone12","stocks_left":11,"opn_flag":"I"},"maxValues":{"product_id":2002,"product_name":"One plus7","stocks_left":33,"opn_flag":"I"},"nullCount":{"product_id":0,"product_name":0,"stocks_left":0,"opn_flag":0}})</td><td>null</td><td>null</td><td>null</td></tr><tr><td>List(true, 1608798278000, part-00001-5a191187-0e1d-418b-9265-6f04a3b69af2-c000.snappy.parquet, 1280, {"numRecords":2,"minValues":{"product_id":2003,"product_name":"Redminote10","stocks_left":14,"opn_flag":"I"},"maxValues":{"product_id":2004,"product_name":"Samsung S10","stocks_left":41,"opn_flag":"I"},"nullCount":{"product_id":0,"product_name":0,"stocks_left":0,"opn_flag":0}})</td><td>null</td><td>null</td><td>null</td></tr></tbody></table></div>

# %%
# %sql
select * from demo_db.product_delta_table
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_id</th><th>product_name</th><th>stocks_left</th><th>opn_flag</th></tr></thead><tbody><tr><td>2003</td><td>Redminote10</td><td>41</td><td>I</td></tr><tr><td>2004</td><td>Samsung S10</td><td>14</td><td>I</td></tr><tr><td>2001</td><td>Iphone12</td><td>11</td><td>I</td></tr><tr><td>2002</td><td>One plus7</td><td>33</td><td>I</td></tr></tbody></table></div>

# %%
# %sql
select * from demo_db.product_parquet_table
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_id</th><th>product_name</th><th>stocks_left</th><th>opn_flag</th></tr></thead><tbody><tr><td>2003</td><td>Redminote10</td><td>41</td><td>I</td></tr><tr><td>2004</td><td>Samsung S10</td><td>14</td><td>I</td></tr><tr><td>2001</td><td>Iphone12</td><td>11</td><td>I</td></tr><tr><td>2002</td><td>One plus7</td><td>33</td><td>I</td></tr></tbody></table></div>

# %%
l=[(2001, "Iphone12", "eleven", "I"), (2002, "One plus7", 33.22, "I"), (2003, "Redminote10", 41, "I"), (2004, "Samsung S10", 14, "I")]
rdd = sc.parallelize(l)
schema_Rdd=rdd.map(lambda x : Row(product_id = int(x[0]), product_name = x[1], stocks_left = str(x[2]), opn_flag=x[3] ))
type_changed_df=spark.createDataFrame(schema_Rdd)
display(type_changed_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_id</th><th>product_name</th><th>stocks_left</th><th>opn_flag</th></tr></thead><tbody><tr><td>2001</td><td>Iphone12</td><td>eleven</td><td>I</td></tr><tr><td>2002</td><td>One plus7</td><td>33.22</td><td>I</td></tr><tr><td>2003</td><td>Redminote10</td><td>41</td><td>I</td></tr><tr><td>2004</td><td>Samsung S10</td><td>14</td><td>I</td></tr></tbody></table></div>

# %%
type_changed_df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- product_id: long (nullable = true)
# -- product_name: string (nullable = true)
# -- stocks_left: string (nullable = true)
# -- opn_flag: string (nullable = true)
#
# </div>

# %%
(type_changed_df.repartition(2).write.format("parquet").mode("overwrite").saveAsTable(f'{database_name}.{parquet_table_name}'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
select * from demo_db.product_parquet_table
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_id</th><th>product_name</th><th>stocks_left</th><th>opn_flag</th></tr></thead><tbody><tr><td>2001</td><td>Iphone12</td><td>eleven</td><td>I</td></tr><tr><td>2002</td><td>One plus7</td><td>33.22</td><td>I</td></tr><tr><td>2003</td><td>Redminote10</td><td>41</td><td>I</td></tr><tr><td>2004</td><td>Samsung S10</td><td>14</td><td>I</td></tr></tbody></table></div>

# %%
(type_changed_df.repartition(2).write.format("delta").mode("overwrite").saveAsTable(f'{database_name}.{delta_table_name}'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">AnalysisException</span>                         Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-2590864419616873&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span><span class="ansi-blue-fg">(</span>type_changed_df<span class="ansi-blue-fg">.</span>repartition<span class="ansi-blue-fg">(</span><span class="ansi-cyan-fg">2</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>write<span class="ansi-blue-fg">.</span>format<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;delta&#34;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>mode<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;overwrite&#34;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>saveAsTable<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">f&#39;{database_name}.{delta_table_name}&#39;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/readwriter.py</span> in <span class="ansi-cyan-fg">saveAsTable</span><span class="ansi-blue-fg">(self, name, format, mode, partitionBy, **options)</span>
# <span class="ansi-green-intense-fg ansi-bold">    869</span>         <span class="ansi-green-fg">if</span> format <span class="ansi-green-fg">is</span> <span class="ansi-green-fg">not</span> <span class="ansi-green-fg">None</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">    870</span>             self<span class="ansi-blue-fg">.</span>format<span class="ansi-blue-fg">(</span>format<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-fg">--&gt; 871</span><span class="ansi-red-fg">         </span>self<span class="ansi-blue-fg">.</span>_jwrite<span class="ansi-blue-fg">.</span>saveAsTable<span class="ansi-blue-fg">(</span>name<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    872</span>
# <span class="ansi-green-intense-fg ansi-bold">    873</span>     <span class="ansi-blue-fg">@</span>since<span class="ansi-blue-fg">(</span><span class="ansi-cyan-fg">1.4</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py</span> in <span class="ansi-cyan-fg">__call__</span><span class="ansi-blue-fg">(self, *args)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1303</span>         answer <span class="ansi-blue-fg">=</span> self<span class="ansi-blue-fg">.</span>gateway_client<span class="ansi-blue-fg">.</span>send_command<span class="ansi-blue-fg">(</span>command<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1304</span>         return_value = get_return_value(
# <span class="ansi-green-fg">-&gt; 1305</span><span class="ansi-red-fg">             answer, self.gateway_client, self.target_id, self.name)
# </span><span class="ansi-green-intense-fg ansi-bold">   1306</span>
# <span class="ansi-green-intense-fg ansi-bold">   1307</span>         <span class="ansi-green-fg">for</span> temp_arg <span class="ansi-green-fg">in</span> temp_args<span class="ansi-blue-fg">:</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/utils.py</span> in <span class="ansi-cyan-fg">deco</span><span class="ansi-blue-fg">(*a, **kw)</span>
# <span class="ansi-green-intense-fg ansi-bold">    131</span>                 <span class="ansi-red-fg"># Hide where the exception came from that shows a non-Pythonic</span>
# <span class="ansi-green-intense-fg ansi-bold">    132</span>                 <span class="ansi-red-fg"># JVM exception message.</span>
# <span class="ansi-green-fg">--&gt; 133</span><span class="ansi-red-fg">                 </span>raise_from<span class="ansi-blue-fg">(</span>converted<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    134</span>             <span class="ansi-green-fg">else</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">    135</span>                 <span class="ansi-green-fg">raise</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/utils.py</span> in <span class="ansi-cyan-fg">raise_from</span><span class="ansi-blue-fg">(e)</span>
#
# <span class="ansi-red-fg">AnalysisException</span>: Failed to merge fields &#39;stocks_left&#39; and &#39;stocks_left&#39;. Failed to merge incompatible data types LongType and StringType;;</div>

# %%
# %sql
select * from demo_db.product_delta_table
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_id</th><th>product_name</th><th>stocks_left</th><th>opn_flag</th></tr></thead><tbody><tr><td>2003</td><td>Redminote10</td><td>41</td><td>I</td></tr><tr><td>2004</td><td>Samsung S10</td><td>14</td><td>I</td></tr><tr><td>2001</td><td>Iphone12</td><td>11</td><td>I</td></tr><tr><td>2002</td><td>One plus7</td><td>33</td><td>I</td></tr></tbody></table></div>

# %%
l=[(2001, "Iphone12", 11, "I", "new"), (2002, "One plus7", 33, "I", "old"), (2003, "Redminote10", 41, "I", "new"), (2004, "Samsung S10", 14, "I", "old")]
rdd = sc.parallelize(l)
schema_Rdd=rdd.map(lambda x : Row(product_id = int(x[0]), product_name = x[1], stocks_left = (x[2]), opn_flag=x[3], new_col=x[4] ))
newcol_df=spark.createDataFrame(schema_Rdd)
display(newcol_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_id</th><th>product_name</th><th>stocks_left</th><th>opn_flag</th><th>new_col</th></tr></thead><tbody><tr><td>2001</td><td>Iphone12</td><td>11</td><td>I</td><td>new</td></tr><tr><td>2002</td><td>One plus7</td><td>33</td><td>I</td><td>old</td></tr><tr><td>2003</td><td>Redminote10</td><td>41</td><td>I</td><td>new</td></tr><tr><td>2004</td><td>Samsung S10</td><td>14</td><td>I</td><td>old</td></tr></tbody></table></div>

# %%
(newcol_df.repartition(2).write.format("parquet").mode("append").option("mergeSchema", True).saveAsTable(f'{database_name}.{parquet_table_name}'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">AnalysisException</span>                         Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-2590864419616877&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span><span class="ansi-blue-fg">(</span>newcol_df<span class="ansi-blue-fg">.</span>repartition<span class="ansi-blue-fg">(</span><span class="ansi-cyan-fg">2</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>write<span class="ansi-blue-fg">.</span>format<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;parquet&#34;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>mode<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;append&#34;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>option<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;mergeSchema&#34;</span><span class="ansi-blue-fg">,</span> <span class="ansi-green-fg">True</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>saveAsTable<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">f&#39;{database_name}.{parquet_table_name}&#39;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/readwriter.py</span> in <span class="ansi-cyan-fg">saveAsTable</span><span class="ansi-blue-fg">(self, name, format, mode, partitionBy, **options)</span>
# <span class="ansi-green-intense-fg ansi-bold">    869</span>         <span class="ansi-green-fg">if</span> format <span class="ansi-green-fg">is</span> <span class="ansi-green-fg">not</span> <span class="ansi-green-fg">None</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">    870</span>             self<span class="ansi-blue-fg">.</span>format<span class="ansi-blue-fg">(</span>format<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-fg">--&gt; 871</span><span class="ansi-red-fg">         </span>self<span class="ansi-blue-fg">.</span>_jwrite<span class="ansi-blue-fg">.</span>saveAsTable<span class="ansi-blue-fg">(</span>name<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    872</span>
# <span class="ansi-green-intense-fg ansi-bold">    873</span>     <span class="ansi-blue-fg">@</span>since<span class="ansi-blue-fg">(</span><span class="ansi-cyan-fg">1.4</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py</span> in <span class="ansi-cyan-fg">__call__</span><span class="ansi-blue-fg">(self, *args)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1303</span>         answer <span class="ansi-blue-fg">=</span> self<span class="ansi-blue-fg">.</span>gateway_client<span class="ansi-blue-fg">.</span>send_command<span class="ansi-blue-fg">(</span>command<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1304</span>         return_value = get_return_value(
# <span class="ansi-green-fg">-&gt; 1305</span><span class="ansi-red-fg">             answer, self.gateway_client, self.target_id, self.name)
# </span><span class="ansi-green-intense-fg ansi-bold">   1306</span>
# <span class="ansi-green-intense-fg ansi-bold">   1307</span>         <span class="ansi-green-fg">for</span> temp_arg <span class="ansi-green-fg">in</span> temp_args<span class="ansi-blue-fg">:</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/utils.py</span> in <span class="ansi-cyan-fg">deco</span><span class="ansi-blue-fg">(*a, **kw)</span>
# <span class="ansi-green-intense-fg ansi-bold">    131</span>                 <span class="ansi-red-fg"># Hide where the exception came from that shows a non-Pythonic</span>
# <span class="ansi-green-intense-fg ansi-bold">    132</span>                 <span class="ansi-red-fg"># JVM exception message.</span>
# <span class="ansi-green-fg">--&gt; 133</span><span class="ansi-red-fg">                 </span>raise_from<span class="ansi-blue-fg">(</span>converted<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    134</span>             <span class="ansi-green-fg">else</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">    135</span>                 <span class="ansi-green-fg">raise</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/utils.py</span> in <span class="ansi-cyan-fg">raise_from</span><span class="ansi-blue-fg">(e)</span>
#
# <span class="ansi-red-fg">AnalysisException</span>: The column number of the existing table demo_db.product_parquet_table(struct&lt;product_id:bigint,product_name:string,stocks_left:string,opn_flag:string&gt;) doesn&#39;t match the data schema(struct&lt;product_id:bigint,product_name:string,stocks_left:bigint,opn_flag:string,new_col:string&gt;);</div>

# %%
(newcol_df.repartition(2).write.format("delta").mode("append").saveAsTable(f'{database_name}.{delta_table_name}'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">AnalysisException</span>                         Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-2590864419616878&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span><span class="ansi-blue-fg">(</span>newcol_df<span class="ansi-blue-fg">.</span>repartition<span class="ansi-blue-fg">(</span><span class="ansi-cyan-fg">2</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>write<span class="ansi-blue-fg">.</span>format<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;delta&#34;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>mode<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;append&#34;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>saveAsTable<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">f&#39;{database_name}.{delta_table_name}&#39;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/readwriter.py</span> in <span class="ansi-cyan-fg">saveAsTable</span><span class="ansi-blue-fg">(self, name, format, mode, partitionBy, **options)</span>
# <span class="ansi-green-intense-fg ansi-bold">    869</span>         <span class="ansi-green-fg">if</span> format <span class="ansi-green-fg">is</span> <span class="ansi-green-fg">not</span> <span class="ansi-green-fg">None</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">    870</span>             self<span class="ansi-blue-fg">.</span>format<span class="ansi-blue-fg">(</span>format<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-fg">--&gt; 871</span><span class="ansi-red-fg">         </span>self<span class="ansi-blue-fg">.</span>_jwrite<span class="ansi-blue-fg">.</span>saveAsTable<span class="ansi-blue-fg">(</span>name<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    872</span>
# <span class="ansi-green-intense-fg ansi-bold">    873</span>     <span class="ansi-blue-fg">@</span>since<span class="ansi-blue-fg">(</span><span class="ansi-cyan-fg">1.4</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py</span> in <span class="ansi-cyan-fg">__call__</span><span class="ansi-blue-fg">(self, *args)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1303</span>         answer <span class="ansi-blue-fg">=</span> self<span class="ansi-blue-fg">.</span>gateway_client<span class="ansi-blue-fg">.</span>send_command<span class="ansi-blue-fg">(</span>command<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1304</span>         return_value = get_return_value(
# <span class="ansi-green-fg">-&gt; 1305</span><span class="ansi-red-fg">             answer, self.gateway_client, self.target_id, self.name)
# </span><span class="ansi-green-intense-fg ansi-bold">   1306</span>
# <span class="ansi-green-intense-fg ansi-bold">   1307</span>         <span class="ansi-green-fg">for</span> temp_arg <span class="ansi-green-fg">in</span> temp_args<span class="ansi-blue-fg">:</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/utils.py</span> in <span class="ansi-cyan-fg">deco</span><span class="ansi-blue-fg">(*a, **kw)</span>
# <span class="ansi-green-intense-fg ansi-bold">    131</span>                 <span class="ansi-red-fg"># Hide where the exception came from that shows a non-Pythonic</span>
# <span class="ansi-green-intense-fg ansi-bold">    132</span>                 <span class="ansi-red-fg"># JVM exception message.</span>
# <span class="ansi-green-fg">--&gt; 133</span><span class="ansi-red-fg">                 </span>raise_from<span class="ansi-blue-fg">(</span>converted<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    134</span>             <span class="ansi-green-fg">else</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">    135</span>                 <span class="ansi-green-fg">raise</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/utils.py</span> in <span class="ansi-cyan-fg">raise_from</span><span class="ansi-blue-fg">(e)</span>
#
# <span class="ansi-red-fg">AnalysisException</span>: A schema mismatch detected when writing to the Delta table (Table ID: e689f527-4391-441d-b7de-3975f971bae1).
# To enable schema migration using DataFrameWriter or DataStreamWriter, please set:
# &#39;.option(&#34;mergeSchema&#34;, &#34;true&#34;)&#39;.
# For other operations, set the session configuration
# spark.databricks.delta.schema.autoMerge.enabled to &#34;true&#34;. See the documentation
# specific to the operation for details.
#
# Table schema:
# root
# -- product_id: long (nullable = true)
# -- product_name: string (nullable = true)
# -- stocks_left: long (nullable = true)
# -- opn_flag: string (nullable = true)
#
#
# Data schema:
# root
# -- product_id: long (nullable = true)
# -- product_name: string (nullable = true)
# -- stocks_left: long (nullable = true)
# -- opn_flag: string (nullable = true)
# -- new_col: string (nullable = true)
#
#          ;</div>

# %%
(newcol_df.repartition(2).write.format("delta").mode("append").option("mergeSchema", True).saveAsTable(f'{database_name}.{delta_table_name}'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
select * from demo_db.product_delta_table
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_id</th><th>product_name</th><th>stocks_left</th><th>opn_flag</th><th>new_col</th></tr></thead><tbody><tr><td>2003</td><td>Redminote10</td><td>41</td><td>I</td><td>new</td></tr><tr><td>2004</td><td>Samsung S10</td><td>14</td><td>I</td><td>old</td></tr><tr><td>2001</td><td>Iphone12</td><td>11</td><td>I</td><td>new</td></tr><tr><td>2002</td><td>One plus7</td><td>33</td><td>I</td><td>old</td></tr><tr><td>2003</td><td>Redminote10</td><td>41</td><td>I</td><td>null</td></tr><tr><td>2004</td><td>Samsung S10</td><td>14</td><td>I</td><td>null</td></tr><tr><td>2001</td><td>Iphone12</td><td>11</td><td>I</td><td>null</td></tr><tr><td>2002</td><td>One plus7</td><td>33</td><td>I</td><td>null</td></tr></tbody></table></div>

# %%
l=[(2001, "Iphone12", 10, "U", "new"), (2002, "One plus7", 12, "U", "old"), (2003, "Redminote10", 20, "U", "new"), (2004, "Samsung S10", 0, "D", "old")]
rdd = sc.parallelize(l)
schema_Rdd=rdd.map(lambda x : Row(product_id = int(x[0]), product_name = x[1], stocks_left = (x[2]), opn_flag=x[3], new_col=x[4] ))
merge_df=spark.createDataFrame(schema_Rdd)
display(merge_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_id</th><th>product_name</th><th>stocks_left</th><th>opn_flag</th><th>new_col</th></tr></thead><tbody><tr><td>2001</td><td>Iphone12</td><td>10</td><td>U</td><td>new</td></tr><tr><td>2002</td><td>One plus7</td><td>12</td><td>U</td><td>old</td></tr><tr><td>2003</td><td>Redminote10</td><td>20</td><td>U</td><td>new</td></tr><tr><td>2004</td><td>Samsung S10</td><td>0</td><td>D</td><td>old</td></tr></tbody></table></div>

# %%
merge_df.createOrReplaceTempView('source_table')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
spark.sql("""
          MERGE INTO demo_db.product_delta_table target_table
          USING source_table
          ON source_table.product_id = target_table.product_id
          WHEN MATCHED AND source_table.opn_flag = 'U'
          THEN
          UPDATE SET *
          WHEN MATCHED AND source_table.opn_flag = 'D'
          THEN DELETE
          WHEN NOT MATCHED and source_table.opn_flag = 'I'
          THEN INSERT *
          """)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[38]: DataFrame[]</div>

# %%
# %sql
select * from demo_db.product_delta_table
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_id</th><th>product_name</th><th>stocks_left</th><th>opn_flag</th><th>new_col</th></tr></thead><tbody><tr><td>2001</td><td>Iphone12</td><td>10</td><td>U</td><td>new</td></tr><tr><td>2001</td><td>Iphone12</td><td>10</td><td>U</td><td>new</td></tr><tr><td>2002</td><td>One plus7</td><td>12</td><td>U</td><td>old</td></tr><tr><td>2002</td><td>One plus7</td><td>12</td><td>U</td><td>old</td></tr><tr><td>2003</td><td>Redminote10</td><td>20</td><td>U</td><td>new</td></tr><tr><td>2003</td><td>Redminote10</td><td>20</td><td>U</td><td>new</td></tr></tbody></table></div>

# %%
# %sql

describe history demo_db.product_delta_table
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>userName</th><th>operation</th><th>operationParameters</th><th>job</th><th>notebook</th><th>clusterId</th><th>readVersion</th><th>isolationLevel</th><th>isBlindAppend</th><th>operationMetrics</th><th>userMetadata</th></tr></thead><tbody><tr><td>3</td><td>2020-12-24T08:24:53.000+0000</td><td>256656542290214</td><td>ravi.tiwari@nagarro.com</td><td>MERGE</td><td>Map(predicate -> (source_table.`product_id` = target_table.`product_id`), matchedPredicates -> [{"predicate":"(source_table.`opn_flag` = 'U')","actionType":"update"},{"predicate":"(source_table.`opn_flag` = 'D')","actionType":"delete"}], notMatchedPredicates -> [{"predicate":"(source_table.`opn_flag` = 'I')","actionType":"insert"}])</td><td>null</td><td>List(4496351827461139)</td><td>1222-072542-imp140</td><td>2</td><td>WriteSerializable</td><td>false</td><td>Map(numTargetRowsCopied -> 0, numTargetRowsDeleted -> 2, numTargetFilesAdded -> 1, numTargetRowsInserted -> 0, numTargetRowsUpdated -> 6, numOutputRows -> 6, numSourceRows -> 4, numTargetFilesRemoved -> 3)</td><td>null</td></tr><tr><td>2</td><td>2020-12-24T08:24:49.000+0000</td><td>256656542290214</td><td>ravi.tiwari@nagarro.com</td><td>WRITE</td><td>Map(mode -> Append, partitionBy -> [])</td><td>null</td><td>List(4496351827461139)</td><td>1222-072542-imp140</td><td>1</td><td>WriteSerializable</td><td>true</td><td>Map(numFiles -> 1, numOutputBytes -> 1551, numOutputRows -> 4)</td><td>null</td></tr><tr><td>1</td><td>2020-12-24T08:24:42.000+0000</td><td>256656542290214</td><td>ravi.tiwari@nagarro.com</td><td>CREATE OR REPLACE TABLE AS SELECT</td><td>Map(isManaged -> true, description -> null, partitionBy -> [], properties -> {})</td><td>null</td><td>List(4496351827461139)</td><td>1222-072542-imp140</td><td>0</td><td>WriteSerializable</td><td>false</td><td>Map(numFiles -> 2, numOutputBytes -> 2545, numOutputRows -> 4)</td><td>null</td></tr><tr><td>0</td><td>2020-12-24T08:24:39.000+0000</td><td>256656542290214</td><td>ravi.tiwari@nagarro.com</td><td>CREATE OR REPLACE TABLE AS SELECT</td><td>Map(isManaged -> true, description -> null, partitionBy -> [], properties -> {})</td><td>null</td><td>List(4496351827461139)</td><td>1222-072542-imp140</td><td>null</td><td>WriteSerializable</td><td>false</td><td>Map(numFiles -> 2, numOutputBytes -> 2545, numOutputRows -> 4)</td><td>null</td></tr></tbody></table></div>

# %%
# %sql

select * from demo_db.product_delta_table version as of 0
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_id</th><th>product_name</th><th>stocks_left</th><th>opn_flag</th></tr></thead><tbody><tr><td>2003</td><td>Redminote10</td><td>41</td><td>I</td></tr><tr><td>2004</td><td>Samsung S10</td><td>14</td><td>I</td></tr><tr><td>2001</td><td>Iphone12</td><td>11</td><td>I</td></tr><tr><td>2002</td><td>One plus7</td><td>33</td><td>I</td></tr></tbody></table></div>

# %%
# %sql

select * from demo_db.product_delta_table timestamp as of '2020-12-24T08:24:49.000+0000'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_id</th><th>product_name</th><th>stocks_left</th><th>opn_flag</th><th>new_col</th></tr></thead><tbody><tr><td>2003</td><td>Redminote10</td><td>41</td><td>I</td><td>new</td></tr><tr><td>2004</td><td>Samsung S10</td><td>14</td><td>I</td><td>old</td></tr><tr><td>2001</td><td>Iphone12</td><td>11</td><td>I</td><td>new</td></tr><tr><td>2002</td><td>One plus7</td><td>33</td><td>I</td><td>old</td></tr><tr><td>2003</td><td>Redminote10</td><td>41</td><td>I</td><td>null</td></tr><tr><td>2004</td><td>Samsung S10</td><td>14</td><td>I</td><td>null</td></tr><tr><td>2001</td><td>Iphone12</td><td>11</td><td>I</td><td>null</td></tr><tr><td>2002</td><td>One plus7</td><td>33</td><td>I</td><td>null</td></tr></tbody></table></div>

# %%
# %fs

ls dbfs:/user/hive/warehouse/demo_db.db/product_delta_table/_delta_log
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/user/hive/warehouse/demo_db.db/product_delta_table/_delta_log/00000000000000000000.crc</td><td>00000000000000000000.crc</td><td>89</td></tr><tr><td>dbfs:/user/hive/warehouse/demo_db.db/product_delta_table/_delta_log/00000000000000000000.json</td><td>00000000000000000000.json</td><td>2063</td></tr><tr><td>dbfs:/user/hive/warehouse/demo_db.db/product_delta_table/_delta_log/00000000000000000001.crc</td><td>00000000000000000001.crc</td><td>89</td></tr><tr><td>dbfs:/user/hive/warehouse/demo_db.db/product_delta_table/_delta_log/00000000000000000001.json</td><td>00000000000000000001.json</td><td>1764</td></tr><tr><td>dbfs:/user/hive/warehouse/demo_db.db/product_delta_table/_delta_log/00000000000000000002.crc</td><td>00000000000000000002.crc</td><td>89</td></tr><tr><td>dbfs:/user/hive/warehouse/demo_db.db/product_delta_table/_delta_log/00000000000000000002.json</td><td>00000000000000000002.json</td><td>1587</td></tr><tr><td>dbfs:/user/hive/warehouse/demo_db.db/product_delta_table/_delta_log/00000000000000000003.crc</td><td>00000000000000000003.crc</td><td>89</td></tr><tr><td>dbfs:/user/hive/warehouse/demo_db.db/product_delta_table/_delta_log/00000000000000000003.json</td><td>00000000000000000003.json</td><td>1858</td></tr><tr><td>dbfs:/user/hive/warehouse/demo_db.db/product_delta_table/_delta_log/__tmp_path_dir/</td><td>__tmp_path_dir/</td><td>0</td></tr></tbody></table></div>

# %%
display(spark.read.json('dbfs:/user/hive/warehouse/demo_db.db/product_delta_table/_delta_log/00000000000000000000.json'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>add</th><th>commitInfo</th><th>metaData</th><th>protocol</th></tr></thead><tbody><tr><td>null</td><td>List(1222-072542-imp140, false, WriteSerializable, List(4496351827461139), CREATE OR REPLACE TABLE AS SELECT, List(2, 2545, 4), List(null, true, [], {}), 1608798278869, 256656542290214, ravi.tiwari@nagarro.com)</td><td>null</td><td>null</td></tr><tr><td>null</td><td>null</td><td>null</td><td>List(1, 2)</td></tr><tr><td>null</td><td>null</td><td>List(1608798278222, List(parquet), e689f527-4391-441d-b7de-3975f971bae1, List(), {"type":"struct","fields":[{"name":"product_id","type":"long","nullable":true,"metadata":{}},{"name":"product_name","type":"string","nullable":true,"metadata":{}},{"name":"stocks_left","type":"long","nullable":true,"metadata":{}},{"name":"opn_flag","type":"string","nullable":true,"metadata":{}}]})</td><td>null</td></tr><tr><td>List(true, 1608798278000, part-00000-e696e70b-981d-4d92-ab99-d3cfd354a15d-c000.snappy.parquet, 1265, {"numRecords":2,"minValues":{"product_id":2001,"product_name":"Iphone12","stocks_left":11,"opn_flag":"I"},"maxValues":{"product_id":2002,"product_name":"One plus7","stocks_left":33,"opn_flag":"I"},"nullCount":{"product_id":0,"product_name":0,"stocks_left":0,"opn_flag":0}})</td><td>null</td><td>null</td><td>null</td></tr><tr><td>List(true, 1608798278000, part-00001-5a191187-0e1d-418b-9265-6f04a3b69af2-c000.snappy.parquet, 1280, {"numRecords":2,"minValues":{"product_id":2003,"product_name":"Redminote10","stocks_left":14,"opn_flag":"I"},"maxValues":{"product_id":2004,"product_name":"Samsung S10","stocks_left":41,"opn_flag":"I"},"nullCount":{"product_id":0,"product_name":0,"stocks_left":0,"opn_flag":0}})</td><td>null</td><td>null</td><td>null</td></tr></tbody></table></div>

# %%
display(spark.read.json('dbfs:/user/hive/warehouse/demo_db.db/product_delta_table/_delta_log/00000000000000000002.json'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>add</th><th>commitInfo</th><th>metaData</th></tr></thead><tbody><tr><td>null</td><td>List(1222-072542-imp140, true, WriteSerializable, List(4496351827461139), WRITE, List(1, 1551, 4), List(Append, []), 1, 1608798289670, 256656542290214, ravi.tiwari@nagarro.com)</td><td>null</td></tr><tr><td>null</td><td>null</td><td>List(1608798278222, List(parquet), e689f527-4391-441d-b7de-3975f971bae1, List(), {"type":"struct","fields":[{"name":"product_id","type":"long","nullable":true,"metadata":{}},{"name":"product_name","type":"string","nullable":true,"metadata":{}},{"name":"stocks_left","type":"long","nullable":true,"metadata":{}},{"name":"opn_flag","type":"string","nullable":true,"metadata":{}},{"name":"new_col","type":"string","nullable":true,"metadata":{}}]})</td></tr><tr><td>List(true, 1608798289000, part-00000-2e62174e-18bd-4f13-b32a-ccecea671c75-c000.snappy.parquet, 1551, {"numRecords":4,"minValues":{"product_id":2001,"product_name":"Iphone12","stocks_left":11,"opn_flag":"I","new_col":"new"},"maxValues":{"product_id":2004,"product_name":"Samsung S10","stocks_left":41,"opn_flag":"I","new_col":"old"},"nullCount":{"product_id":0,"product_name":0,"stocks_left":0,"opn_flag":0,"new_col":0}})</td><td>null</td><td>null</td></tr></tbody></table></div>

# %%
display(spark.read.json('dbfs:/user/hive/warehouse/demo_db.db/product_delta_table/_delta_log/00000000000000000003.json'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>add</th><th>commitInfo</th><th>remove</th></tr></thead><tbody><tr><td>null</td><td>List(1222-072542-imp140, false, WriteSerializable, List(4496351827461139), MERGE, List(6, 4, 1, 3, 0, 2, 0, 6), List([{"predicate":"(source_table.`opn_flag` = 'U')","actionType":"update"},{"predicate":"(source_table.`opn_flag` = 'D')","actionType":"delete"}], [{"predicate":"(source_table.`opn_flag` = 'I')","actionType":"insert"}], (source_table.`product_id` = target_table.`product_id`)), 2, 1608798293357, 256656542290214, ravi.tiwari@nagarro.com)</td><td>null</td></tr><tr><td>null</td><td>null</td><td>List(true, 1608798293356, part-00000-2e62174e-18bd-4f13-b32a-ccecea671c75-c000.snappy.parquet)</td></tr><tr><td>null</td><td>null</td><td>List(true, 1608798293356, part-00001-a3062155-b29a-49a4-bfa6-26d4f4d1f4b1-c000.snappy.parquet)</td></tr><tr><td>null</td><td>null</td><td>List(true, 1608798293356, part-00000-04e318b5-516a-4ea2-a80a-3aa5c27f1232-c000.snappy.parquet)</td></tr><tr><td>List(true, 1608798293000, part-00000-9994436b-0cbc-46a2-94aa-8b96f877e48c-c000.snappy.parquet, 1625, {"numRecords":6,"minValues":{"product_id":2001,"product_name":"Iphone12","stocks_left":10,"opn_flag":"U","new_col":"new"},"maxValues":{"product_id":2003,"product_name":"Redminote10","stocks_left":20,"opn_flag":"U","new_col":"old"},"nullCount":{"product_id":0,"product_name":0,"stocks_left":0,"opn_flag":0,"new_col":0}})</td><td>null</td><td>null</td></tr></tbody></table></div>
